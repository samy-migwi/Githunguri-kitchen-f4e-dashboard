# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Administrator\Desktop\ds\f4e\githunguri1\Githunguri-kitchen-f4e-dashboard\data\data_processed\df_upto_30_01_26.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Kitchen                       588 non-null    object
#  1   School                        588 non-null    object
#  2   School_Type                   588 non-null    object
#  3   Date                          588 non-null    object
#  4   Menu                          588 non-null    object
#  5   Rice_variant                  588 non-null    object
#  6   Projected_Kids                588 non-null    int64
#  7   Actual_Meals_Served           588 non-null    int64
#  8   Successful_Taps               588 non-null    int64
#  9   F4E_Supported_Kids            588 non-null    int64
#  10  Teachers                      588 non-null    int64
#  11  Staff_Meals                   588 non-null    int64
#  12  Failed_Taps                   588 non-null    int64
#  13  New_Registrations             588 non-null    int64
#  14  New_Tags_Replaced             588 non-null    int64
#  15  Rice_Remaining                585 non-null    float64
#  16  B_W_G_Remaining               588 non-null    float64
#  17  Missed_Food                   97 non-null     float64
#  18  Next_Day_Projection_Students  588 non-null    int64
#  19  Next_Day_Projection_Teachers  584 non-null    float64
#  20  Next_Day_Projection_Staff     98 non-null     float64
#  21  Start_Taping                  588 non-null    object
#  22  Stop_Taping                   588 non-null    object
#  23  Lunch_Time_Min                588 non-null    int64
#  24  Projection_Comment            97 non-null     object
#  25  Comment_1                     588 non-null    object
#  26  Comment_2                     588 non-null    object
#  27  Comment_3                     588 non-null    object
#  28  Comment_4                     588 non-null    object
#  29  Reported_By                   588 non-null    object
#  30  file_date                     588 non-null    int64
# dtypes: float64(5), int64(12), object(14)
# memory usage: 142.5+ KB

# %%
df["School"].nunique()
# Out:
# 30

# %%
for i in df["School"].unique():
    print(i)
# Out:
# Githioro Primary
# Githima Primary
# Gatina Primary
# Kiawairia Primary
# Githiga Primary
# Kanyore Primary
# Kindiga Primary
# Ihiga Primary
# Mitahato Primary
# Gathangari Primary
# Gataka Primary
# Gathaithi Primary
# Mathanja Priamry
# Kiambururu Primary
# Gathiruini Primary
# Matuguta Primary
# Gatitu Primary
# Kiawaiguru Primary
# Gitombo Primary
# Kahunira Primary
# Kiababu Primary
# Ciiko Primary
# Gikang'A Kageche Secondary
# Gitiha Secondary
# Matuguta Secondary
# Gathaithi Secondary
# Githunguri Technical & Secondary
# Kahunira Secondary
# Kiambururu Secondary
# Kiawairia Secondary
# Mukuyu Secondary
# Githunguri Technical Secondary

# %%
Total_meals_served=df['Actual_Meals_Served'].sum()
print(Total_meals_served)
# Out:
# 169855

# %%
df

# %%
df['Actual_Meals_Served'].groupby(df['School']).sum().sort_values(ascending=True)
# Out:
# School
# Kiawairia Secondary                   793
# Gathaithi Secondary                  1830
# Matuguta Secondary                   2081
# Gitiha Secondary                     2451
# Kahunira Secondary                   2575
# Kiawairia Primary                    2642
# Ihiga Primary                        3185
# Githunguri Technical & Secondary     3263
# Kiambururu Secondary                 3348
# Gitombo Primary                      3425
# Kindiga Primary                      3592
# Mathanja Priamry                     3739
# Kiawaiguru Primary                   4198
# Gikang'A Kageche Secondary           4710
# Gathiruini Primary                   4713
# Mukuyu Secondary                     4752
# Githima Primary                      4969
# Kiababu Primary                      5176
# Kiambururu Primary                   5264
# Gataka Primary                       5479
# Githioro Primary                     6329
# Gatitu Primary                       7198
# Githiga Primary                      7323
# Gathangari Primary                   7704
# Gatina Primary                       8591
# Gathaithi Primary                    8832
# Matuguta Primary                     8887
# Kanyore Primary                     11611
# Kahunira Primary                    13756
# Ciiko Primary                       17303
# Name: Actual_Meals_Served, dtype: int64

# %%
Total_meals_served=df['Actual_Meals_Served'].sum()
print(Total_meals_served)
# Out:
# 169855

# %%
Total_projected_meals=df['Projected_Kids'].sum()
print(Total_projected_meals)
# Out:
# 171637

# %%
#esimation presision
presision=(Total_meals_served/Total_projected_meals).round(2)
print(presision)
# Out:
# 0.99

# %%
# Generate the existing plots
projected_vs_actual_fig = go.Figure()
projected_vs_actual_fig.add_trace(
    go.Bar(x=filtered_df["School"], y=filtered_df["Projected_Kids"], name='Projected Kids', marker_color='blue',
            text=filtered_df["Projected_Kids"], textposition='outside')
)
projected_vs_actual_fig.add_trace(
    go.Bar(x=filtered_df["School"], y=filtered_df["Actual_Meals_Served"], name='Actual_Meals_Served', marker_color='green',
            text=filtered_df["Actual_Meals_Served"], textposition='outside')
)
projected_vs_actual_fig.add_trace(
    go.Bar(x=filtered_df["School"], y=filtered_df["Failed_Taps"], name='Failed Taps', marker_color='orange',
            text=filtered_df["Failed_Taps"], textposition='outside')
)
projected_vs_actual_fig.update_layout(
    title=f"Projected vs Actual Meals Served on {selected_date}",
    xaxis_title="School",
    yaxis_title="Number of Kids",
    barmode='group',
    margin=dict(l=50, r=50, t=50, b=50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Generate the existing plots
# ----> 2 projected_vs_actual_fig = go.Figure()
#       3 projected_vs_actual_fig.add_trace(
#       4     go.Bar(x=filtered_df["School"], y=filtered_df["Projected_Kids"], name='Projected Kids', marker_color='blue',
#       5             text=filtered_df["Projected_Kids"], textposition='outside')
#       6 )
#       7 projected_vs_actual_fig.add_trace(
#       8     go.Bar(x=filtered_df["School"], y=filtered_df["Actual_Meals_Served"], name='Actual_Meals_Served', marker_color='green',
#       9             text=filtered_df["Actual_Meals_Served"], textposition='outside')
#      10 )
#
# NameError: name 'go' is not defined
